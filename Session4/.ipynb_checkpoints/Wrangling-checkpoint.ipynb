# %%
# Add libraries
import pandas as pd

# Import data 
bp = pd.read_csv("Backpack.csv", index_col = 0)

# Remove unnamed columns
bp.filter(["BackpackWeight", "BodyWeight", "Ratio", "BackProblems", "Major", "Year", "Sex", "Status", "Units"])
# Out:
#     BackpackWeight  BodyWeight     Ratio  BackProblems      Major  Year  \
# 0                9         125  0.072000             1        Bio     3
# 1                8         180  0.044444             0         EE     2
# 2                8         170  0.047059             0         CM     3
# 3                8         135  0.059259             0        Bus     3
# 4               12         125  0.096000             1         CS     3
# 5                6         105  0.057143             0         LS     3
# 6               10         125  0.080000             1         LS     3
# 7                5         165  0.030303             0        Bio     3
# 8               20         170  0.117647             0        CSC     2
# 9               14         117  0.119658             1         EE     2
# 10              10         270  0.037037             0        AGB     3
# 11              18         160  0.112500             1       Mate     1
# ...

# %%
bp.head()
# Out:
#    BackpackWeight  BodyWeight     Ratio  BackProblems Major  Year     Sex  \
# 0               9         125  0.072000             1   Bio     3  Female
# 1               8         180  0.044444             0    EE     2  Female
# 2               8         170  0.047059             0    CM     3    Male
# 3               8         135  0.059259             0   Bus     3  Female
# 4              12         125  0.096000             1    CS     3  Female
#
#   Status  Units
# 0      U     13
# 1      U     14
# 2      U     15
# 3      U     15
# 4      U     12

# %%
bp.to_csv("Backpack.csv", index = False)
